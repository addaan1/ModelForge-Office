# %% [markdown]
# # EDA and Data Audit
# Project: `playground-series-s6e5`

# %%
from pathlib import Path
import pandas as pd
RAW = Path('../raw')
print('Raw files:', [p.name for p in RAW.glob('*')])
train = pd.read_csv(RAW / 'train.csv')
print(train.shape)
train.head()
